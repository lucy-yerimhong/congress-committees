# %%
import numpy as np
import pandas as pd
import requests
import json
import dotenv
import os
import yaml
import llm

# %% [markdown]
# ### Getting Current and Historical Committee Assignment from unitedstates/congress-legislators

# %%
# Current committees
url = "https://raw.githubusercontent.com/unitedstates/congress-legislators/main/committees-current.yaml"
response = requests.get(url)
current = yaml.safe_load(response.text)

# %%
pd.DataFrame(current).head()
# Out:
#     type                                   name  \
# 0  house         House Committee on Agriculture
# 1  house      House Committee on Appropriations
# 2  house      House Committee on Armed Services
# 3  house  House Committee on Financial Services
# 4  house          House Committee on the Budget
#
#                                     url  \
# 0        https://agriculture.house.gov/
# 1     https://appropriations.house.gov/
# 2      https://armedservices.house.gov/
# 3  https://financialservices.house.gov/
# 4             https://budget.house.gov/
#
#                                        minority_url thomas_id  \
# 0         https://republicans-agriculture.house.gov      HSAG
# 1     https://republicans-appropriations.house.gov/      HSAP
# 2      https://republicans-armedservices.house.gov/      HSAS
# 3  https://republicans-financialservices.house.gov/      HSBA
# 4               https://democrats-budget.house.gov/      HSBU
#
#   house_committee_id                                      subcommittees  \
# 0                 AG  [{'name': 'Forestry and Horticulture', 'thomas...
# 1                 AP  [{'name': 'Agriculture, Rural Development, Foo...
# 2                 AS  [{'name': 'Tactical Air and Land Forces', 'tho...
# 3                 BA  [{'name': 'Capital Markets', 'thomas_id': '16'...
# 4                 BU                                                NaN
#
#                                    address           phone  \
# 0     1301 LHOB; Washington, DC 20515-6001  (202) 225-2171
# 1  H307 CAPITOL; Washington, DC 20515-6015  (202) 225-2771
# 2     2216 RHOB; Washington, DC 20515-6035  (202) 225-4151
# 3     2129 RHOB; Washington, DC 20515-6050  (202) 225-7502
# 4      204 CHOB; Washington, DC 20515-6065  (202) 226-7270
#
#                                             rss_url  \
# 0  https://agriculture.house.gov/Rss.aspx?GroupID=1
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4            https://budget.house.gov/news/rss.aspx
#
#                                         jurisdiction  \
# 0  The House Committee on Agriculture has legisla...
# 1  The House Committee on Appropriations is respo...
# 2  The House Committee on Armed Services has legi...
# 3  The House Financial Services Committee has jur...
# 4  The House Committee on the Budget is responsib...
#
#                  youtube_id                         jurisdiction_source  \
# 0  UCOWh2WJxPywHIaccDWb8Mvg                                         NaN
# 1  UCMaSlF09S0fpoRshS2t_7XA     https://appropriations.house.gov/about/
# 2  UCD506yORW2voSanqEgLOUIQ       https://armedservices.house.gov/about
# 3  UCiGw0gRK-daU7Xv4oDMr9Hg  https://financialservices.house.gov/about/
# 4  UCwzia2rpHJkowAXK-IF9E0w             https://budget.house.gov/about/
#
#                              minority_rss_url senate_committee_id wikipedia
# 0                                         NaN                 NaN       NaN
# 1                                         NaN                 NaN       NaN
# 2                                         NaN                 NaN       NaN
# 3                                         NaN                 NaN       NaN
# 4  https://democrats-budget.house.gov/rss.xml                 NaN       NaN

# %%
# Current membership
url = "https://raw.githubusercontent.com/unitedstates/congress-legislators/main/committee-membership-current.yaml"
response = requests.get(url)
current_membership = yaml.safe_load(response.text)

# %%
pd.DataFrame(current_membership).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.DataFrame(current_membership).head()
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/core/internals/construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/core/internals/construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/core/internals/construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length

# %%
# Historical committees (since 1973; 93rd Congress)
url = "https://raw.githubusercontent.com/unitedstates/congress-legislators/main/committees-historical.yaml"
response = requests.get(url)
historical = yaml.safe_load(response.text)

# %%
pd.DataFrame(historical)
# Out:
#       type                                               name thomas_id  \
# 0    house  House Select Subcommittee on the Coronavirus P...      HSVC
# 1    house  House Select Subcommittee on the Weaponization...      HSFD
# 2    house  House Task Force on the Attempted Assassinatio...      HSZT
# 3    house                 House Committee on Energy (Ad Hoc)      HHAH
# 4    house             House Committee on Committees (Select)      HLCQ
# ..     ...                                                ...       ...
# 65   house  House Select Committee on Economic Disparity a...      HSEF
# 66   house  House Select Committee on the Modernization of...      HSMH
# 67   house  House Select Committee to Investigate the Janu...      HSIJ
# 68  senate  Commission on Security and Cooperation in Euro...      JCSE
# 69  senate  Senate Committee on Caucus on International Na...      SCNC
#
#    house_committee_id       congresses  \
# 0                  VC       [117, 118]
# 1                  FD            [118]
# 2                  ZT            [118]
# 3                  AH             [95]
# 4                  CQ         [93, 96]
# ..                ...              ...
# 65                 EF            [117]
# 66                 MH            [117]
# 67                 IJ            [117]
# 68                NaN       [112, 113]
# 69                NaN  [112, 113, 114]
#
#                                                 names subcommittees  \
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3                             {95: 'Energy (Ad Hoc)'}           NaN
# 4   {93: 'Committees (Select)', 96: 'Committees (S...           NaN
# ..                                                ...           ...
# 65  {117: 'Economic Disparity and Fairness in Grow...           NaN
# 66                 {117: 'Modernization of Congress'}           NaN
# 67  {117: 'Investigate the January 6th Attack on t...           NaN
# 68  {112: 'Commission on Security and Cooperation ...           NaN
# 69  {112: 'Caucus on International Narcotics Contr...           NaN
#
#    senate_committee_id
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 65                 NaN
# 66                 NaN
# 67                 NaN
# 68                 NaN
# 69                 NaN
#
# [70 rows x 8 columns]

# %%
### Data from Stewart's code
stewart_house = pd.read_excel("../data/Stewart_House_103-117.xls")
stewart_senate = pd.read_excel("../data/Stewart_Senate_103-117.xlsx")

pd.DataFrame(stewart_house).head()
pd.DataFrame(stewart_senate).head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 ### Data from Stewart's code
# ----> 2 stewart_house = pd.read_excel("../data/Stewart_House_103-117.xls")
#       3 stewart_senate = pd.read_excel("../data/Stewart_Senate_103-117.xlsx")
#       5 pd.DataFrame(stewart_house).head()
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/io/excel/_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File /opt/miniconda3/envs/cmt/lib/python3.13/site-packages/pandas/io/common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Stewart_House_103-117.xls'
